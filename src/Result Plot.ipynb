# %%
import pandas as pd

df = pd.read_csv("../assets/a2/throughput.csv")
df['AP1_MBytes'] = df['AP1_Bytes'] / (1024 * 1024)
df['AP1_MBytes'] = df['AP1_MBytes'].round(3)
df['AP2_MBytes'] = df['AP2_Bytes'] / (1024 * 1024)
df['AP2_MBytes'] = df['AP2_MBytes'].round(3)
df.head()
# Out:
#    Time  AP1_Bytes  AP2_Bytes  AP1_MBytes  AP2_MBytes
# 0     1          0          0       0.000       0.000
# 1     2     534336     148672       0.510       0.142
# 2     3    1264448     446016       1.206       0.425
# 3     4    1726656     943552       1.647       0.900
# 4     5    2228608    1470528       2.125       1.402

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


plt.figure(figsize=(10, 6))
plt.plot(df['Time'].values, df['AP1_MBytes'].values, label='AP1_Bytes', color='blue')
plt.plot(df['Time'].values, df['AP2_MBytes'].values, label='AP2_Bytes', color='red')
plt.xlabel('Time')
plt.ylabel('Mega Bytes')
plt.title('AP1_MBytes vs AP2_MBytes over Time')
plt.legend()
plt.grid(True)
plt.show()
